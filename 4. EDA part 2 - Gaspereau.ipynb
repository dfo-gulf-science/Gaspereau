# %% [markdown]
# # import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

sns.set_theme()

# jupyter notebook full-width display
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# pandas formatting
pd.set_option('display.float_format', '{:.3f}'.format)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_pickle('cleaned_dataset.pickle')

# %% [markdown]
# # Data Types and Stats

# %%
df.dtypes
# Out:
# YEAR                         Int32
# MM                           Int32
# DD                           Int32
# WEEK                         Int32
# SITE                        object
# PERIOD                      object
# CONDITION                   object
# FISH_NO                      Int32
# FL_WET                       Int32
# FL_FROZEN                    Int32
# FL_STD                      object
# WEIGHT                     float64
# SPECIES                     object
# SEX                         object
# MATURITY                     Int32
# GONAD_WEIGHT               float64
# 1st Person Aging            object
# AGE                          Int32
# FSP                          Int32
# Comments                    object
# 2nd Person Aging            object
# AGE.1                        Int32
# FSP.1                        Int32
# Comments.1                  object
# Envelop Comments            object
# AGE_notes                   object
# FSP_notes                   object
# DATETIME            datetime64[ns]
# dtype: object

# %%
df.describe(include='all', datetime_is_numeric=True).T
# Out:
#                      count  unique                                   top  \
# YEAR             35619.000     NaN                                   NaN
# MM               35619.000     NaN                                   NaN
# DD               35619.000     NaN                                   NaN
# WEEK             22371.000     NaN                                   NaN
# SITE                 35501      78                                    12
# PERIOD               30417       2                                    AM
# CONDITION            35424       2                                Frozen
# FISH_NO          35619.000     NaN                                   NaN
# FL_WET            9655.000     NaN                                   NaN
# FL_FROZEN        25490.000     NaN                                   NaN
# FL_STD           34981.000 226.000                               258.000
# WEIGHT           35318.000     NaN                                   NaN
# SPECIES              35392       3                                     A
# SEX                  35391       3                                     F
# MATURITY         34992.000     NaN                                   NaN
# GONAD_WEIGHT     17282.000     NaN                                   NaN
# 1st Person Aging      7118       1                                    JM
# AGE              31480.000     NaN                                   NaN
# FSP              31257.000     NaN                                   NaN
# Comments              1885     856                                 NICE
# 2nd Person Aging       390       1                                    LF
# AGE.1              378.000     NaN                                   NaN
# FSP.1              378.000     NaN                                   NaN
# Comments.1              22      17                           poor scales
# Envelop Comments       625      73  parasites; round worms, less than 5.
# AGE_notes            31568      24                                     3
# FSP_notes            31350      26                                     3
# DATETIME             35619     NaN                                   NaN
#
#                      freq                           mean                  min  \
# YEAR                  NaN                       2000.901             1983.000
# MM                    NaN                          5.392                4.000
# DD                    NaN                         16.121                1.000
# WEEK                  NaN                          5.050                1.000
# SITE                 6668                            NaN                  NaN
# PERIOD              16340                            NaN                  NaN
# CONDITION           25704                            NaN                  NaN
# FISH_NO               NaN                         17.770                1.000
# FL_WET                NaN                        253.504              150.000
# FL_FROZEN             NaN                        247.317              112.000
# FL_STD           1309.000                            NaN                  NaN
# WEIGHT                NaN                        217.944               15.100
# SPECIES             30885                            NaN                  NaN
# SEX                 17621                            NaN                  NaN
# MATURITY              NaN                          3.762                0.000
# GONAD_WEIGHT          NaN                         37.250                0.000
# 1st Person Aging     7118                            NaN                  NaN
# AGE                   NaN                          3.829                0.000
# FSP                   NaN                          3.366                0.000
# Comments              233                            NaN                  NaN
# 2nd Person Aging      390                            NaN                  NaN
# AGE.1                 NaN                          3.823                2.000
# FSP.1                 NaN                          3.214                2.000
# Comments.1              5                            NaN                  NaN
# Envelop Comments      187                            NaN                  NaN
# AGE_notes           12903                            NaN                  NaN
# FSP_notes           20329                            NaN                  NaN
# DATETIME              NaN  2001-04-22 00:38:09.834077312  1983-05-09 00:00:00
#
#                                   25%                  50%  \
# YEAR                         1990.000             2000.000
# MM                              5.000                5.000
# DD                              9.000               16.000
# WEEK                            4.000                5.000
# SITE                              NaN                  NaN
# PERIOD                            NaN                  NaN
# CONDITION                         NaN                  NaN
# FISH_NO                         9.000               17.000
# FL_WET                        240.000              253.000
# FL_FROZEN                     234.000              247.000
# FL_STD                            NaN                  NaN
# WEIGHT                        174.300              211.200
# SPECIES                           NaN                  NaN
# SEX                               NaN                  NaN
# MATURITY                        4.000                4.000
# GONAD_WEIGHT                   27.400               36.100
# 1st Person Aging                  NaN                  NaN
# AGE                             3.000                4.000
# FSP                             3.000                3.000
# Comments                          NaN                  NaN
# 2nd Person Aging                  NaN                  NaN
# AGE.1                           3.000                4.000
# FSP.1                           3.000                3.000
# Comments.1                        NaN                  NaN
# Envelop Comments                  NaN                  NaN
# AGE_notes                         NaN                  NaN
# FSP_notes                         NaN                  NaN
# DATETIME          1990-05-31 00:00:00  2000-05-25 00:00:00
#
#                                   75%                  max    std
# YEAR                         2011.000             2019.000 11.021
# MM                              6.000                7.000  0.500
# DD                             24.000               31.000  8.768
# WEEK                            6.000                9.000  2.005
# SITE                              NaN                  NaN    NaN
# PERIOD                            NaN                  NaN    NaN
# CONDITION                         NaN                  NaN    NaN
# FISH_NO                        25.000              100.000 11.672
# FL_WET                        267.000              358.000 19.313
# FL_FROZEN                     260.000              366.000 19.577
# FL_STD                            NaN                  NaN    NaN
# WEIGHT                        255.100             1934.000 61.426
# SPECIES                           NaN                  NaN    NaN
# SEX                               NaN                  NaN    NaN
# MATURITY                        4.000                6.000  0.706
# GONAD_WEIGHT                   46.200              766.000 16.292
# 1st Person Aging                  NaN                  NaN    NaN
# AGE                             4.000               10.000  0.917
# FSP                             4.000               33.000  1.039
# Comments                          NaN                  NaN    NaN
# 2nd Person Aging                  NaN                  NaN    NaN
# AGE.1                           4.000                7.000  0.960
# FSP.1                           3.000                5.000  0.482
# Comments.1                        NaN                  NaN    NaN
# Envelop Comments                  NaN                  NaN    NaN
# AGE_notes                         NaN                  NaN    NaN
# FSP_notes                         NaN                  NaN    NaN
# DATETIME          2011-06-17 00:00:00  2019-06-28 00:00:00    NaN

# %% [markdown]
# # Histograms

# %%
columns_to_print = ['YEAR', 'MM', 'DD', 'WEEK', 'PERIOD', 'CONDITION', 'FISH_NO',
       'FL_WET', 'FL_FROZEN', 'FL_STD', 'WEIGHT', 'SPECIES', 'SEX', 'MATURITY',
       'GONAD_WEIGHT', '1st Person Aging', 'AGE', 'FSP', '2nd Person Aging', 'AGE.1', 'FSP.1']

for column in columns_to_print:
    print('--------------------------------------------------\nHistogram:', column.upper())
    
    plt.figure(figsize=(14, 4))
    
    n_unique = df[column].nunique()
    
    max_bins = 100
    if n_unique <= max_bins:
        bins = n_unique
    else:
        bins = max_bins
    
    df[column].hist(bins=bins)
    
    plt.show()
# Out:
# --------------------------------------------------
# Histogram: YEAR
# --------------------------------------------------
# Histogram: MM
# --------------------------------------------------
# Histogram: DD
# --------------------------------------------------
# Histogram: WEEK
# --------------------------------------------------
# Histogram: PERIOD
# --------------------------------------------------
# Histogram: CONDITION
# --------------------------------------------------
# Histogram: FISH_NO
# --------------------------------------------------
# Histogram: FL_WET
# --------------------------------------------------
# Histogram: FL_FROZEN
# --------------------------------------------------
# Histogram: FL_STD
# --------------------------------------------------
# Histogram: WEIGHT
# --------------------------------------------------
# Histogram: SPECIES
# --------------------------------------------------
# Histogram: SEX
# --------------------------------------------------
# Histogram: MATURITY
# --------------------------------------------------
# Histogram: GONAD_WEIGHT
# --------------------------------------------------
# Histogram: 1ST PERSON AGING
# --------------------------------------------------
# Histogram: AGE
# --------------------------------------------------
# Histogram: FSP
# --------------------------------------------------
# Histogram: 2ND PERSON AGING
# --------------------------------------------------
# Histogram: AGE.1
# --------------------------------------------------
# Histogram: FSP.1

# %%
possible_maturity = [1, 2, 3, 4, 5, 6]

for i, maturity in enumerate(possible_maturity):

    plt.figure(figsize=(14, 3))
    xmin, xmax = 1983, 2019
    bins = 2019 - 1983 + 1
    bins_plot = [(x/(bins+1))*(xmax-xmin)+xmin for x in range(bins+2)] 

    df.loc[df.MATURITY == maturity, 'YEAR'].hist(bins=bins_plot, label=maturity, color=sns.color_palette()[i])
    
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

    plt.show()

# %% [markdown]
# # Correlation

# %%
plt.figure(figsize=(8,8))
palette = sns.blend_palette([sns.color_palette()[0], '#ffffff', sns.color_palette()[1]], 3, as_cmap=True)
sns.heatmap(df.corr(), cmap=palette, annot=True, center=0, vmin=-1, vmax=1, fmt='.1f', annot_kws={"size": 10}, cbar=False)
plt.title('\nCorrelation Heatmap\n')
plt.show()

# %% [markdown]
# # Time Series

# %%
features = {
    'CONDITION': 'categorical',
    'FL_WET': 'integer', 
    'FL_FROZEN': 'integer',
    'FL_STD': 'float', 
    'WEIGHT': 'float', 
    'SPECIES': 'categorical', 
    'SEX': 'categorical', 
    'MATURITY': 'integer', 
    'GONAD_WEIGHT': 'float', 
    'AGE': 'integer', 
    'FSP': 'integer', 
    'AGE.1': 'integer', 
    'FSP.1': 'integer'
}

for feature in features:
    
    print('\n-------------------------------------------------------\n', feature.upper(), sep='')
    plt.figure(figsize=(14, 4))
    
    if features[feature] == 'float':
        plot = sns.lineplot(x=df.DATETIME.dt.year, y=df[feature], errorbar=('pi', 50), color=sns.color_palette()[0])
        print('FLOAT')
    elif features[feature] == 'integer':  # convert to float or get a ValueError
        plot = sns.lineplot(x=df.DATETIME.dt.year, y=df[feature].astype(float), errorbar=('pi', 50), color=sns.color_palette()[1])
        print('INT')
    elif features[feature] == 'categorical':
        plot = sns.lineplot(x=df.DATETIME.dt.year, y=df[feature], errorbar=('pi', 50), color=sns.color_palette()[2])
        print('CATEGORICAL')    
    
    # show entire dataset time period for all plots
    plot.set_xlim(1982, 2022)
    
    plt.show()
# Out:
# -------------------------------------------------------
# CONDITION
# CATEGORICAL
# -------------------------------------------------------
# FL_WET
# INT
# -------------------------------------------------------
# FL_FROZEN
# INT
# -------------------------------------------------------
# FL_STD
# FLOAT
# -------------------------------------------------------
# WEIGHT
# FLOAT
# -------------------------------------------------------
# SPECIES
# CATEGORICAL
# -------------------------------------------------------
# SEX
# CATEGORICAL
# -------------------------------------------------------
# MATURITY
# INT
# -------------------------------------------------------
# GONAD_WEIGHT
# FLOAT
# -------------------------------------------------------
# AGE
# INT
# -------------------------------------------------------
# FSP
# INT
# -------------------------------------------------------
# AGE.1
# INT
# -------------------------------------------------------
# FSP.1
# INT
